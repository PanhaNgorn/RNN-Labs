# %%
# Exercise 1 Create class Library for a library to keep track of their book. For each book, we want to know many copy does the library still has on shelf. If a copy is borrowed, who borrow it, what is their contact, phone and email, when did it was borrow and when it is expected to be return.

# %%
# Exercise 2 
class BankAccount:
    def __init__(self, owner_name):
        self.owner_name = owner_name
        self.balance = 0.0
        self.transactions = []

    def deposit(self, amount, date):
        if amount > 0:
            self.balance += amount
            self.transactions.append({
                'type': 'deposit',
                'amount': amount,
                'date': date
            })
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount, date):
        if 0 < amount <= self.balance:
            self.balance -= amount
            self.transactions.append({
                'type': 'withdrawal',
                'amount': amount,
                'date': date
            })
        else:
            print("Infufficient funds")

    def get_balance(self):
        return self.balance

    def get_transactions(self):
        return self.transactions

# %%
account = BankAccount("Virak")

# %%
account.deposit(1000, "2024-01-01")
account.get_balance()
# Out:
# 1000.0

# %%
account.withdraw(700, "2024-01-02")
account.get_balance()
# Out:
# Infufficient funds
# 600.0

# %%
account.get_transactions()
# Out:
# [{'type': 'deposit', 'amount': 1000, 'date': '2024-01-01'},
#  {'type': 'withdrawal', 'amount': 200, 'date': '2024-01-02'}]

# %%
# Exercise 3

# %% [markdown]
# Pytorch

# %%
# 1. Create a 3×4 tensor A and a 4×2 tensor B. Compute their matrix product C = A @ B. Print the tensors A, B, and C, along with their shapes.
import torch 
A = torch.randn(3, 4)
B = torch.randn(4, 2)

C = A @ B

# %%
A, A.shape
# Out:
# (tensor([[ 1.4896,  0.2020,  1.3114,  0.4171],
#          [ 0.6121, -0.5147, -0.5171,  1.2795],
#          [ 0.2576, -1.1938,  1.8695,  0.3695]]),
#  torch.Size([3, 4]))

# %%
B, B.shape
# Out:
# (tensor([[ 0.6548, -1.7505],
#          [-1.3462,  0.4373],
#          [ 0.6996,  0.3560],
#          [-0.7183,  0.0464]]),
#  torch.Size([4, 2]))

# %%
C, C.shape
# Out:
# (tensor([[ 1.3214, -2.0329],
#          [-0.1871, -1.4212],
#          [ 2.8183, -0.2904]]),
#  torch.Size([3, 2]))

# %%
import matplotlib.pyplot as plt

x = torch.linspace(0, 3.14159 * 2, 200)
y = torch.sin(x)

plt.plot(x, y)
plt.title("Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid()
plt.show()

# %%
x = torch.linspace(-5, 5, steps=100)
y = x**3 - 2 * x ** 2 - 3 * x +1

plt.plot(x, y)
plt.title("Cubic Function")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.show()

# %%
x = torch.linspace(0, 4 * 3.14159, 100)
y1 = torch.cos(x)
y2 = torch.cos(2 * x)

plt.plot(x, y1, label='cos(x)')
plt.plot(x, y2, label='cos(2x)')
plt.legend()
plt.title("Cosine Functions")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.show()
